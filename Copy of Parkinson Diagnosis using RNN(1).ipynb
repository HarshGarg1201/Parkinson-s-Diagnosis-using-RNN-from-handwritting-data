# %%
import pandas as pd
import warnings
import requests, zipfile, io, os
import numpy as np
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
warnings.filterwarnings('ignore')

# %%
# download file from url, extract it and store it in the dest_folder
def download_and_extract(url, dest_folder):
  r = requests.get(url)
  z = zipfile.ZipFile(io.BytesIO(r.content))
  z.extractall(dest_folder)

# %%
# define folders and urls
healthy_path = './healthy'
healthy_url = 'http://wwwp.fc.unesp.br/~papa/pub/datasets/Handpd/NewHealthy/Signal.zip'
parkinson_path = './parkinson'
parkinson_url = 'http://wwwp.fc.unesp.br/~papa/pub/datasets/Handpd/NewPatients/Signal.zip'

# %%
download_and_extract(healthy_url, healthy_path)

# %%
download_and_extract(parkinson_url, parkinson_path)

# %%
# actual downloaded signals
healthy_signals = f'{healthy_path}/Signal/'
parkinson_signals = f'{parkinson_path}/Signal/'

# %%
# define Input and labels (0 = healthy, parkinson = 1)
X = []
y = []
seq = 500

# %%
# create dataset with sequence length 500

# healthy signals
for filename in os.listdir(healthy_signals):
  if filename.endswith('txt'):
    df = pd.read_csv(healthy_signals + filename, sep='\s+', header=None, comment='#')
    count = len(df.index) // seq
    for i in range(count):
      X.append((df.iloc[i * seq : (i + 1) * seq]).to_numpy())
      y.append(0)

# parkinson signals
for filename in os.listdir(parkinson_signals):
  if filename.endswith('txt'):
    df = pd.read_csv(parkinson_signals + filename, sep='\s+', header=None, comment='#')
    count = len(df.index) // seq
    for i in range(count):
      X.append((df.iloc[i * seq : (i + 1) * seq]).to_numpy())
      y.append(1)

# %%
len(X)
# Out:
# 29088

# %%
# convert lists to np arrays
X = np.array(X)
y = np.array(y)

# %%
X.shape
# Out:
# (29088, 500, 6)

# %%
y.shape
# Out:
# (29088,)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_valid = scaler.transform(X_valid.reshape(-1, X_valid.shape[-1])).reshape(X_valid.shape)
X_test = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

# %%
model = keras.models.Sequential([
keras.layers.Conv1D(filters=20, kernel_size=4, strides=2, padding="valid", input_shape=[None, 6]),
keras.layers.GRU(128, return_sequences=True),
keras.layers.GRU(128),
keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
checkpoint_filepath = "model.h5"
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
model.fit(X_train, y_train, epochs = 1000, batch_size = 32, validation_data=(X_valid, y_valid), callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/1000
# 589/589 [==============================] - 14s 24ms/step - loss: 0.6057 - accuracy: 0.6748 - val_loss: 0.5924 - val_accuracy: 0.6932
# Epoch 2/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.5550 - accuracy: 0.7167 - val_loss: 0.5225 - val_accuracy: 0.7454
# Epoch 3/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.4744 - accuracy: 0.7744 - val_loss: 0.4258 - val_accuracy: 0.7997
# Epoch 4/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.4001 - accuracy: 0.8155 - val_loss: 0.3709 - val_accuracy: 0.8315
# Epoch 5/1000
# 589/589 [==============================] - 14s 24ms/step - loss: 0.3508 - accuracy: 0.8401 - val_loss: 0.3336 - val_accuracy: 0.8460
# Epoch 6/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.2996 - accuracy: 0.8687 - val_loss: 0.2982 - val_accuracy: 0.8602
# Epoch 7/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.2603 - accuracy: 0.8887 - val_loss: 0.2917 - val_accuracy: 0.8725
# Epoch 8/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.2246 - accuracy: 0.9042 - val_loss: 0.2644 - val_accuracy: 0.8846
# Epoch 9/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.2044 - accuracy: 0.9143 - val_loss: 0.2581 - val_accuracy: 0.8909
# Epoch 10/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.1718 - accuracy: 0.9293 - val_loss: 0.2573 - val_accuracy: 0.8937
# Epoch 11/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.1497 - accuracy: 0.9417 - val_loss: 0.2394 - val_accuracy: 0.9037
# Epoch 12/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.1312 - accuracy: 0.9477 - val_loss: 0.2408 - val_accuracy: 0.9111
# Epoch 13/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.1189 - accuracy: 0.9525 - val_loss: 0.2509 - val_accuracy: 0.9049
# Epoch 14/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0966 - accuracy: 0.9618 - val_loss: 0.2477 - val_accuracy: 0.9109
# Epoch 15/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0861 - accuracy: 0.9659 - val_loss: 0.2636 - val_accuracy: 0.9088
# Epoch 16/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0828 - accuracy: 0.9670 - val_loss: 0.3093 - val_accuracy: 0.9039
# Epoch 17/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0736 - accuracy: 0.9723 - val_loss: 0.2853 - val_accuracy: 0.9079
# Epoch 18/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0640 - accuracy: 0.9753 - val_loss: 0.2830 - val_accuracy: 0.9132
# Epoch 19/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0626 - accuracy: 0.9772 - val_loss: 0.2695 - val_accuracy: 0.9115
# Epoch 20/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0586 - accuracy: 0.9789 - val_loss: 0.3007 - val_accuracy: 0.9117
# Epoch 21/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0455 - accuracy: 0.9833 - val_loss: 0.3189 - val_accuracy: 0.9102
# Epoch 22/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0525 - accuracy: 0.9808 - val_loss: 0.3036 - val_accuracy: 0.9134
# Epoch 23/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0514 - accuracy: 0.9813 - val_loss: 0.3036 - val_accuracy: 0.9166
# Epoch 24/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0422 - accuracy: 0.9851 - val_loss: 0.3100 - val_accuracy: 0.9168
# Epoch 25/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0347 - accuracy: 0.9882 - val_loss: 0.3325 - val_accuracy: 0.9132
# Epoch 26/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0525 - accuracy: 0.9806 - val_loss: 0.3115 - val_accuracy: 0.9170
# Epoch 27/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0371 - accuracy: 0.9875 - val_loss: 0.3429 - val_accuracy: 0.9088
# Epoch 28/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0414 - accuracy: 0.9849 - val_loss: 0.3361 - val_accuracy: 0.9107
# Epoch 29/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0327 - accuracy: 0.9886 - val_loss: 0.3405 - val_accuracy: 0.9119
# Epoch 30/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0262 - accuracy: 0.9914 - val_loss: 0.3726 - val_accuracy: 0.9090
# Epoch 31/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0374 - accuracy: 0.9863 - val_loss: 0.3665 - val_accuracy: 0.9109
# Epoch 32/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0432 - accuracy: 0.9846 - val_loss: 0.3727 - val_accuracy: 0.9052
# Epoch 33/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0220 - accuracy: 0.9928 - val_loss: 0.3555 - val_accuracy: 0.9147
# Epoch 34/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0312 - accuracy: 0.9889 - val_loss: 0.3923 - val_accuracy: 0.9007
# Epoch 35/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0446 - accuracy: 0.9838 - val_loss: 0.3621 - val_accuracy: 0.9141
# Epoch 36/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0393 - accuracy: 0.9865 - val_loss: 0.3664 - val_accuracy: 0.9111
# Epoch 37/1000
# 589/589 [==============================] - 14s 24ms/step - loss: 0.0225 - accuracy: 0.9928 - val_loss: 0.3919 - val_accuracy: 0.9164
# Epoch 38/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0197 - accuracy: 0.9934 - val_loss: 0.4258 - val_accuracy: 0.9064
# Epoch 39/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0373 - accuracy: 0.9872 - val_loss: 0.3545 - val_accuracy: 0.9149
# Epoch 40/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0429 - accuracy: 0.9854 - val_loss: 0.3584 - val_accuracy: 0.9134
# Epoch 41/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0220 - accuracy: 0.9929 - val_loss: 0.3844 - val_accuracy: 0.9100
# Epoch 42/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0245 - accuracy: 0.9923 - val_loss: 0.3565 - val_accuracy: 0.9204
# Epoch 43/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0243 - accuracy: 0.9919 - val_loss: 0.3642 - val_accuracy: 0.9181
# Epoch 44/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0246 - accuracy: 0.9919 - val_loss: 0.3533 - val_accuracy: 0.9156
# Epoch 45/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0224 - accuracy: 0.9924 - val_loss: 0.3559 - val_accuracy: 0.9240
# Epoch 46/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0362 - accuracy: 0.9881 - val_loss: 0.3904 - val_accuracy: 0.9102
# Epoch 47/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0465 - accuracy: 0.9849 - val_loss: 0.3740 - val_accuracy: 0.9081
# Epoch 48/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0275 - accuracy: 0.9922 - val_loss: 0.3322 - val_accuracy: 0.9230
# Epoch 49/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.3650 - val_accuracy: 0.9240
# Epoch 50/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0190 - accuracy: 0.9944 - val_loss: 0.4648 - val_accuracy: 0.8979
# Epoch 51/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0397 - accuracy: 0.9858 - val_loss: 0.3460 - val_accuracy: 0.9136
# Epoch 52/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0181 - accuracy: 0.9941 - val_loss: 0.3558 - val_accuracy: 0.9192
# Epoch 53/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0140 - accuracy: 0.9952 - val_loss: 0.3635 - val_accuracy: 0.9226
# Epoch 54/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0356 - accuracy: 0.9877 - val_loss: 0.4123 - val_accuracy: 0.9069
# Epoch 55/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0270 - accuracy: 0.9909 - val_loss: 0.3816 - val_accuracy: 0.9198
# Epoch 56/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0152 - accuracy: 0.9954 - val_loss: 0.4074 - val_accuracy: 0.9134
# Epoch 57/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0267 - accuracy: 0.9908 - val_loss: 0.3831 - val_accuracy: 0.9156
# Epoch 58/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0430 - accuracy: 0.9848 - val_loss: 0.3788 - val_accuracy: 0.9113
# Epoch 59/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.3609 - val_accuracy: 0.9173
# Epoch 60/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0194 - accuracy: 0.9944 - val_loss: 0.3858 - val_accuracy: 0.9119
# Epoch 61/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0252 - accuracy: 0.9919 - val_loss: 0.3983 - val_accuracy: 0.9117
# Epoch 62/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0219 - accuracy: 0.9930 - val_loss: 0.3907 - val_accuracy: 0.9096
# Epoch 63/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0326 - accuracy: 0.9885 - val_loss: 0.3664 - val_accuracy: 0.9113
# Epoch 64/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0314 - accuracy: 0.9886 - val_loss: 0.3592 - val_accuracy: 0.9221
# Epoch 65/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0128 - accuracy: 0.9957 - val_loss: 0.3796 - val_accuracy: 0.9215
# Epoch 66/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0172 - accuracy: 0.9950 - val_loss: 0.3878 - val_accuracy: 0.9153
# Epoch 67/1000
# 589/589 [==============================] - 14s 23ms/step - loss: 0.0311 - accuracy: 0.9898 - val_loss: 0.3703 - val_accuracy: 0.9130
# Epoch 68/1000
# 293/589 [=============>................] - ETA: 6s - loss: 0.0234 - accuracy: 0.9919

# %%
model.fit(X_train, y_train, epochs = 20, batch_size = 32, validation_data=(X_valid, y_valid), callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/20
# 582/582 [==============================] - 105s 180ms/step - loss: 0.0699 - accuracy: 0.9747 - val_loss: 0.2885 - val_accuracy: 0.9031
# Epoch 2/20
# 582/582 [==============================] - 105s 180ms/step - loss: 0.0699 - accuracy: 0.9750 - val_loss: 0.2942 - val_accuracy: 0.9042
# Epoch 3/20
# 582/582 [==============================] - 103s 178ms/step - loss: 0.0657 - accuracy: 0.9755 - val_loss: 0.2949 - val_accuracy: 0.9050
# Epoch 4/20
# 582/582 [==============================] - 106s 182ms/step - loss: 0.0590 - accuracy: 0.9783 - val_loss: 0.2872 - val_accuracy: 0.9091
# Epoch 5/20
# 582/582 [==============================] - 108s 185ms/step - loss: 0.0525 - accuracy: 0.9811 - val_loss: 0.3001 - val_accuracy: 0.9132
# Epoch 6/20
# 582/582 [==============================] - 106s 182ms/step - loss: 0.0465 - accuracy: 0.9825 - val_loss: 0.2921 - val_accuracy: 0.9108
# Epoch 7/20
# 582/582 [==============================] - 102s 175ms/step - loss: 0.0651 - accuracy: 0.9752 - val_loss: 0.2916 - val_accuracy: 0.9085
# Epoch 8/20
# 582/582 [==============================] - 95s 163ms/step - loss: 0.0550 - accuracy: 0.9799 - val_loss: 0.2885 - val_accuracy: 0.9134
# Epoch 9/20
# 582/582 [==============================] - 104s 180ms/step - loss: 0.0503 - accuracy: 0.9814 - val_loss: 0.2822 - val_accuracy: 0.9089
# Epoch 10/20
# 582/582 [==============================] - 105s 181ms/step - loss: 0.0701 - accuracy: 0.9744 - val_loss: 0.2867 - val_accuracy: 0.9050
# Epoch 11/20
# 582/582 [==============================] - 107s 183ms/step - loss: 0.0459 - accuracy: 0.9842 - val_loss: 0.2983 - val_accuracy: 0.9123
# Epoch 12/20
# 582/582 [==============================] - 106s 182ms/step - loss: 0.0324 - accuracy: 0.9890 - val_loss: 0.2998 - val_accuracy: 0.9175
# Epoch 13/20
# 582/582 [==============================] - 106s 182ms/step - loss: 0.0526 - accuracy: 0.9816 - val_loss: 0.2951 - val_accuracy: 0.9061
# Epoch 14/20
# 582/582 [==============================] - 105s 181ms/step - loss: 0.0387 - accuracy: 0.9857 - val_loss: 0.2767 - val_accuracy: 0.9181
# Epoch 15/20
# 582/582 [==============================] - 108s 185ms/step - loss: 0.0397 - accuracy: 0.9864 - val_loss: 0.3104 - val_accuracy: 0.9093
# Epoch 16/20
# 582/582 [==============================] - 105s 181ms/step - loss: 0.0649 - accuracy: 0.9768 - val_loss: 0.3287 - val_accuracy: 0.8949
# Epoch 17/20
# 582/582 [==============================] - 105s 180ms/step - loss: 0.0588 - accuracy: 0.9781 - val_loss: 0.2833 - val_accuracy: 0.9121
# Epoch 18/20
# 582/582 [==============================] - 103s 178ms/step - loss: 0.0263 - accuracy: 0.9917 - val_loss: 0.3132 - val_accuracy: 0.9171
# Epoch 19/20
# 582/582 [==============================] - 105s 180ms/step - loss: 0.0397 - accuracy: 0.9860 - val_loss: 0.3011 - val_accuracy: 0.9132
# Epoch 20/20
# 582/582 [==============================] - 102s 176ms/step - loss: 0.0341 - accuracy: 0.9879 - val_loss: 0.3360 - val_accuracy: 0.9067

# %%
model.fit(X_train, y_train, epochs = 20, batch_size = 32, validation_data=(X_valid, y_valid), callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/20
# 582/582 [==============================] - 104s 178ms/step - loss: 0.0548 - accuracy: 0.9813 - val_loss: 0.3195 - val_accuracy: 0.9055
# Epoch 2/20
# 582/582 [==============================] - 104s 179ms/step - loss: 0.0368 - accuracy: 0.9869 - val_loss: 0.2883 - val_accuracy: 0.9166
# Epoch 3/20
# 582/582 [==============================] - 103s 176ms/step - loss: 0.0295 - accuracy: 0.9901 - val_loss: 0.2996 - val_accuracy: 0.9141
# Epoch 4/20
# 582/582 [==============================] - 103s 178ms/step - loss: 0.0482 - accuracy: 0.9830 - val_loss: 0.2958 - val_accuracy: 0.9153
# Epoch 5/20
# 582/582 [==============================] - 103s 177ms/step - loss: 0.0351 - accuracy: 0.9889 - val_loss: 0.3020 - val_accuracy: 0.9160
# Epoch 6/20
# 582/582 [==============================] - 104s 179ms/step - loss: 0.0256 - accuracy: 0.9910 - val_loss: 0.3180 - val_accuracy: 0.9115
# Epoch 7/20
# 582/582 [==============================] - 97s 167ms/step - loss: 0.0272 - accuracy: 0.9912 - val_loss: 0.3067 - val_accuracy: 0.9168
# Epoch 8/20
# 582/582 [==============================] - 103s 177ms/step - loss: 0.0479 - accuracy: 0.9840 - val_loss: 0.3275 - val_accuracy: 0.9125
# Epoch 9/20
# 582/582 [==============================] - 107s 183ms/step - loss: 0.0399 - accuracy: 0.9854 - val_loss: 0.2921 - val_accuracy: 0.9147
# Epoch 10/20
# 582/582 [==============================] - 103s 176ms/step - loss: 0.0417 - accuracy: 0.9849 - val_loss: 0.3357 - val_accuracy: 0.9151
# Epoch 11/20
# 582/582 [==============================] - 103s 178ms/step - loss: 0.0495 - accuracy: 0.9835 - val_loss: 0.2915 - val_accuracy: 0.9205
# Epoch 12/20
# 582/582 [==============================] - 105s 180ms/step - loss: 0.0171 - accuracy: 0.9953 - val_loss: 0.2944 - val_accuracy: 0.9224
# Epoch 13/20
# 582/582 [==============================] - 104s 179ms/step - loss: 0.0208 - accuracy: 0.9937 - val_loss: 0.3372 - val_accuracy: 0.9160
# Epoch 14/20
# 582/582 [==============================] - 107s 183ms/step - loss: 0.0480 - accuracy: 0.9829 - val_loss: 0.3214 - val_accuracy: 0.9136
# Epoch 15/20
# 582/582 [==============================] - 103s 177ms/step - loss: 0.0333 - accuracy: 0.9887 - val_loss: 0.3152 - val_accuracy: 0.9149
# Epoch 16/20
# 582/582 [==============================] - 108s 186ms/step - loss: 0.0172 - accuracy: 0.9950 - val_loss: 0.3258 - val_accuracy: 0.9143
# Epoch 17/20
# 582/582 [==============================] - 106s 182ms/step - loss: 0.0214 - accuracy: 0.9932 - val_loss: 0.3086 - val_accuracy: 0.9211
# Epoch 18/20
# 582/582 [==============================] - 107s 184ms/step - loss: 0.0539 - accuracy: 0.9826 - val_loss: 0.3186 - val_accuracy: 0.9074
# Epoch 19/20
# 582/582 [==============================] - 104s 178ms/step - loss: 0.0487 - accuracy: 0.9836 - val_loss: 0.3205 - val_accuracy: 0.9158
# Epoch 20/20
# 582/582 [==============================] - 99s 170ms/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.3349 - val_accuracy: 0.9186

# %%
model.fit(X_train, y_train, epochs = 20, batch_size = 32, validation_data=(X_valid, y_valid), callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/20
# 582/582 [==============================] - 105s 180ms/step - loss: 0.0293 - accuracy: 0.9894 - val_loss: 0.3594 - val_accuracy: 0.9044
# Epoch 2/20
# 582/582 [==============================] - 105s 180ms/step - loss: 0.0310 - accuracy: 0.9894 - val_loss: 0.2881 - val_accuracy: 0.9226
# Epoch 3/20
# 582/582 [==============================] - 101s 173ms/step - loss: 0.0314 - accuracy: 0.9899 - val_loss: 0.3118 - val_accuracy: 0.9160
# Epoch 4/20
# 582/582 [==============================] - 103s 177ms/step - loss: 0.0252 - accuracy: 0.9915 - val_loss: 0.3282 - val_accuracy: 0.9175
# Epoch 5/20
# 582/582 [==============================] - 106s 182ms/step - loss: 0.0186 - accuracy: 0.9940 - val_loss: 0.3526 - val_accuracy: 0.9186
# Epoch 6/20
# 582/582 [==============================] - 109s 187ms/step - loss: 0.0392 - accuracy: 0.9875 - val_loss: 0.3608 - val_accuracy: 0.9074
# Epoch 7/20
# 582/582 [==============================] - 106s 182ms/step - loss: 0.0299 - accuracy: 0.9901 - val_loss: 0.3192 - val_accuracy: 0.9188
# Epoch 8/20
# 582/582 [==============================] - 107s 184ms/step - loss: 0.0246 - accuracy: 0.9914 - val_loss: 0.3413 - val_accuracy: 0.9145
# Epoch 9/20
# 582/582 [==============================] - 109s 187ms/step - loss: 0.0376 - accuracy: 0.9864 - val_loss: 0.3219 - val_accuracy: 0.9119
# Epoch 10/20
# 582/582 [==============================] - 107s 183ms/step - loss: 0.0275 - accuracy: 0.9911 - val_loss: 0.3884 - val_accuracy: 0.9020
# Epoch 11/20
# 582/582 [==============================] - 108s 185ms/step - loss: 0.0259 - accuracy: 0.9910 - val_loss: 0.3328 - val_accuracy: 0.9168
# Epoch 12/20
# 582/582 [==============================] - 105s 181ms/step - loss: 0.0237 - accuracy: 0.9924 - val_loss: 0.3140 - val_accuracy: 0.9186
# Epoch 13/20
# 582/582 [==============================] - 107s 184ms/step - loss: 0.0339 - accuracy: 0.9882 - val_loss: 0.3307 - val_accuracy: 0.9115
# Epoch 14/20
# 582/582 [==============================] - 108s 186ms/step - loss: 0.0218 - accuracy: 0.9930 - val_loss: 0.3265 - val_accuracy: 0.9117
# Epoch 15/20
# 582/582 [==============================] - 109s 187ms/step - loss: 0.0286 - accuracy: 0.9906 - val_loss: 0.3643 - val_accuracy: 0.9136
# Epoch 16/20
# 582/582 [==============================] - 108s 186ms/step - loss: 0.0312 - accuracy: 0.9900 - val_loss: 0.3629 - val_accuracy: 0.9143
# Epoch 17/20
# 582/582 [==============================] - 108s 186ms/step - loss: 0.0447 - accuracy: 0.9842 - val_loss: 0.3460 - val_accuracy: 0.9110
# Epoch 18/20
# 582/582 [==============================] - 108s 186ms/step - loss: 0.0232 - accuracy: 0.9922 - val_loss: 0.3245 - val_accuracy: 0.9205
# Epoch 19/20
# 582/582 [==============================] - 108s 185ms/step - loss: 0.0237 - accuracy: 0.9928 - val_loss: 0.3379 - val_accuracy: 0.9162
# Epoch 20/20
# 582/582 [==============================] - 109s 186ms/step - loss: 0.0156 - accuracy: 0.9949 - val_loss: 0.3314 - val_accuracy: 0.9205

# %%
model.load_weights(checkpoint_filepath)

# %%
model.evaluate(X_valid, y_valid)

# %%
model.evaluate(X_test, y_test)

# %%
# !ls

# %%
from google.colab import files
files.download('model.h5')

# %%
y_test.shape
# Out:
# (5818,)

# %%
y_train[:10]
# Out:
# array([0, 1, 0, 0, 0, 0, 0, 0, 1, 0])
