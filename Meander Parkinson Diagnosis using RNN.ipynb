# %%
import pandas as pd
import warnings
import re
import requests, zipfile, io, os
import numpy as np
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
warnings.filterwarnings('ignore')

# %%
# download file from url, extract it and store it in the dest_folder
def download_and_extract(url, dest_folder):
  r = requests.get(url)
  z = zipfile.ZipFile(io.BytesIO(r.content))
  z.extractall(dest_folder)

# %%
# define folders and urls
healthy_path = './healthy'
healthy_url = 'http://wwwp.fc.unesp.br/~papa/pub/datasets/Handpd/NewHealthy/Signal.zip'
parkinson_path = './parkinson'
parkinson_url = 'http://wwwp.fc.unesp.br/~papa/pub/datasets/Handpd/NewPatients/Signal.zip'

# %%
download_and_extract(healthy_url, healthy_path)

# %%
download_and_extract(parkinson_url, parkinson_path)

# %%
# actual downloaded signals
healthy_signals = f'{healthy_path}/Signal/'
parkinson_signals = f'{parkinson_path}/Signal/'

# %%
# define Input and labels (0 = healthy, parkinson = 1)
X = []
y = []
seq = 100

# %%
# create dataset with sequence length

# healthy signals
for filename in os.listdir(healthy_signals):
  if re.search('sigMea', filename) is not None:
    df = pd.read_csv(healthy_signals + filename, sep='\s+', header=None, comment='#')
    count = len(df.index) // seq
    for i in range(count):
      X.append((df.iloc[i * seq : (i + 1) * seq]).to_numpy())
      y.append(0)

# parkinson signals
for filename in os.listdir(parkinson_signals):
  if re.search('sigMea', filename) is not None:
    df = pd.read_csv(parkinson_signals + filename, sep='\s+', header=None, comment='#')
    count = len(df.index) // seq
    for i in range(count):
      X.append((df.iloc[i * seq : (i + 1) * seq]).to_numpy())
      y.append(1)

# %%
len(X)
# Out:
# 41358

# %%
# convert lists to np arrays
X = np.array(X)
y = np.array(y)

# %%
X.shape
# Out:
# (41358, 100, 6)

# %%
y.shape
# Out:
# (41358,)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_valid = scaler.transform(X_valid.reshape(-1, X_valid.shape[-1])).reshape(X_valid.shape)

# %%
model = keras.models.Sequential([
keras.layers.GRU(512, return_sequences=True, input_shape=(X_train.shape[1], 6)),
keras.layers.Dropout(0.5),
keras.layers.GRU(256),
keras.layers.Dropout(0.5),
keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
checkpoint_filepath = "model.h5"
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
history = model.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_data=(X_valid, y_valid), callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.5431 - accuracy: 0.7353 - val_loss: 0.5319 - val_accuracy: 0.7325
# Epoch 2/100
# 1034/1034 [==============================] - 21s 20ms/step - loss: 0.4557 - accuracy: 0.7927 - val_loss: 0.4319 - val_accuracy: 0.8130
# Epoch 3/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.4396 - accuracy: 0.8008 - val_loss: 0.4147 - val_accuracy: 0.8115
# Epoch 4/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.3529 - accuracy: 0.8415 - val_loss: 0.3225 - val_accuracy: 0.8598
# Epoch 5/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.3239 - accuracy: 0.8561 - val_loss: 0.2790 - val_accuracy: 0.8780
# Epoch 6/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2829 - accuracy: 0.8754 - val_loss: 0.2625 - val_accuracy: 0.8859
# Epoch 7/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2651 - accuracy: 0.8860 - val_loss: 0.2572 - val_accuracy: 0.8902
# Epoch 8/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.2523 - accuracy: 0.8914 - val_loss: 0.2489 - val_accuracy: 0.8889
# Epoch 9/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2501 - accuracy: 0.8910 - val_loss: 0.2754 - val_accuracy: 0.8744
# Epoch 10/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2364 - accuracy: 0.8982 - val_loss: 0.2411 - val_accuracy: 0.8957
# Epoch 11/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2416 - accuracy: 0.8970 - val_loss: 0.2356 - val_accuracy: 0.8978
# Epoch 12/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2225 - accuracy: 0.9061 - val_loss: 0.2335 - val_accuracy: 0.9057
# Epoch 13/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2156 - accuracy: 0.9102 - val_loss: 0.2428 - val_accuracy: 0.8951
# Epoch 14/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2037 - accuracy: 0.9155 - val_loss: 0.2081 - val_accuracy: 0.9148
# Epoch 15/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2027 - accuracy: 0.9164 - val_loss: 0.2226 - val_accuracy: 0.9099
# Epoch 16/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2023 - accuracy: 0.9156 - val_loss: 0.2155 - val_accuracy: 0.9114
# Epoch 17/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2103 - accuracy: 0.9117 - val_loss: 0.2231 - val_accuracy: 0.9062
# Epoch 18/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1887 - accuracy: 0.9222 - val_loss: 0.2061 - val_accuracy: 0.9162
# Epoch 19/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1799 - accuracy: 0.9260 - val_loss: 0.2076 - val_accuracy: 0.9148
# Epoch 20/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1875 - accuracy: 0.9239 - val_loss: 0.2101 - val_accuracy: 0.9159
# Epoch 21/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1741 - accuracy: 0.9286 - val_loss: 0.1921 - val_accuracy: 0.9230
# Epoch 22/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1640 - accuracy: 0.9345 - val_loss: 0.1802 - val_accuracy: 0.9284
# Epoch 23/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1614 - accuracy: 0.9356 - val_loss: 0.2105 - val_accuracy: 0.9171
# Epoch 24/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1624 - accuracy: 0.9347 - val_loss: 0.2037 - val_accuracy: 0.9223
# Epoch 25/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1726 - accuracy: 0.9308 - val_loss: 0.1827 - val_accuracy: 0.9265
# Epoch 26/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1558 - accuracy: 0.9385 - val_loss: 0.1895 - val_accuracy: 0.9246
# Epoch 27/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1522 - accuracy: 0.9403 - val_loss: 0.1907 - val_accuracy: 0.9218
# Epoch 28/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1511 - accuracy: 0.9409 - val_loss: 0.1836 - val_accuracy: 0.9266
# Epoch 29/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1436 - accuracy: 0.9427 - val_loss: 0.1788 - val_accuracy: 0.9294
# Epoch 30/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1383 - accuracy: 0.9463 - val_loss: 0.1810 - val_accuracy: 0.9302
# Epoch 31/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1420 - accuracy: 0.9439 - val_loss: 0.1922 - val_accuracy: 0.9259
# Epoch 32/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1469 - accuracy: 0.9422 - val_loss: 0.1914 - val_accuracy: 0.9258
# Epoch 33/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1936 - accuracy: 0.9199 - val_loss: 0.2104 - val_accuracy: 0.9119
# Epoch 34/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1897 - accuracy: 0.9217 - val_loss: 0.2052 - val_accuracy: 0.9159
# Epoch 35/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1833 - accuracy: 0.9251 - val_loss: 0.1987 - val_accuracy: 0.9219
# Epoch 36/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1691 - accuracy: 0.9313 - val_loss: 0.1918 - val_accuracy: 0.9234
# Epoch 37/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1922 - accuracy: 0.9202 - val_loss: 0.2076 - val_accuracy: 0.9134
# Epoch 38/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1827 - accuracy: 0.9267 - val_loss: 0.2011 - val_accuracy: 0.9176
# Epoch 39/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1739 - accuracy: 0.9298 - val_loss: 0.2272 - val_accuracy: 0.9084
# Epoch 40/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1771 - accuracy: 0.9286 - val_loss: 0.2017 - val_accuracy: 0.9185
# Epoch 41/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1705 - accuracy: 0.9315 - val_loss: 0.2154 - val_accuracy: 0.9124
# Epoch 42/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1716 - accuracy: 0.9321 - val_loss: 0.2085 - val_accuracy: 0.9185
# Epoch 43/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1735 - accuracy: 0.9285 - val_loss: 0.1961 - val_accuracy: 0.9212
# Epoch 44/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1620 - accuracy: 0.9373 - val_loss: 0.2259 - val_accuracy: 0.9088
# Epoch 45/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1708 - accuracy: 0.9338 - val_loss: 0.1968 - val_accuracy: 0.9199
# Epoch 46/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1670 - accuracy: 0.9348 - val_loss: 0.1983 - val_accuracy: 0.9212
# Epoch 47/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2244 - accuracy: 0.9062 - val_loss: 0.2137 - val_accuracy: 0.9121
# Epoch 48/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1955 - accuracy: 0.9216 - val_loss: 0.2045 - val_accuracy: 0.9218
# Epoch 49/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1713 - accuracy: 0.9320 - val_loss: 0.2084 - val_accuracy: 0.9174
# Epoch 50/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1731 - accuracy: 0.9315 - val_loss: 0.2153 - val_accuracy: 0.9174
# Epoch 51/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1869 - accuracy: 0.9264 - val_loss: 0.1908 - val_accuracy: 0.9260
# Epoch 52/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1791 - accuracy: 0.9269 - val_loss: 0.2121 - val_accuracy: 0.9154
# Epoch 53/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1776 - accuracy: 0.9289 - val_loss: 0.2032 - val_accuracy: 0.9201
# Epoch 54/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1809 - accuracy: 0.9279 - val_loss: 0.2027 - val_accuracy: 0.9196
# Epoch 55/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1890 - accuracy: 0.9248 - val_loss: 0.2022 - val_accuracy: 0.9189
# Epoch 56/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1762 - accuracy: 0.9293 - val_loss: 0.2029 - val_accuracy: 0.9196
# Epoch 57/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1755 - accuracy: 0.9304 - val_loss: 0.1973 - val_accuracy: 0.9238
# Epoch 58/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1832 - accuracy: 0.9254 - val_loss: 0.2134 - val_accuracy: 0.9111
# Epoch 59/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1808 - accuracy: 0.9279 - val_loss: 0.2249 - val_accuracy: 0.9104
# Epoch 60/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1796 - accuracy: 0.9265 - val_loss: 0.1984 - val_accuracy: 0.9196
# Epoch 61/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1762 - accuracy: 0.9297 - val_loss: 0.2045 - val_accuracy: 0.9173
# Epoch 62/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1940 - accuracy: 0.9224 - val_loss: 0.2231 - val_accuracy: 0.9072
# Epoch 63/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1882 - accuracy: 0.9249 - val_loss: 0.2059 - val_accuracy: 0.9184
# Epoch 64/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.2012 - accuracy: 0.9203 - val_loss: 0.2313 - val_accuracy: 0.9044
# Epoch 65/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.2016 - accuracy: 0.9172 - val_loss: 0.2284 - val_accuracy: 0.9061
# Epoch 66/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1929 - accuracy: 0.9217 - val_loss: 0.2098 - val_accuracy: 0.9145
# Epoch 67/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1990 - accuracy: 0.9197 - val_loss: 0.2351 - val_accuracy: 0.9001
# Epoch 68/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.2030 - accuracy: 0.9186 - val_loss: 0.2183 - val_accuracy: 0.9105
# Epoch 69/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2041 - accuracy: 0.9187 - val_loss: 0.2185 - val_accuracy: 0.9056
# Epoch 70/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2324 - accuracy: 0.9047 - val_loss: 0.2307 - val_accuracy: 0.9030
# Epoch 71/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2193 - accuracy: 0.9110 - val_loss: 0.2256 - val_accuracy: 0.9095
# Epoch 72/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.2058 - accuracy: 0.9176 - val_loss: 0.2173 - val_accuracy: 0.9095
# Epoch 73/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.1995 - accuracy: 0.9182 - val_loss: 0.2294 - val_accuracy: 0.9055
# Epoch 74/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.1958 - accuracy: 0.9208 - val_loss: 0.2157 - val_accuracy: 0.9107
# Epoch 75/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2180 - accuracy: 0.9101 - val_loss: 0.2263 - val_accuracy: 0.9067
# Epoch 76/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2076 - accuracy: 0.9152 - val_loss: 0.2210 - val_accuracy: 0.9079
# Epoch 77/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2235 - accuracy: 0.9077 - val_loss: 0.2450 - val_accuracy: 0.8998
# Epoch 78/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.2236 - accuracy: 0.9093 - val_loss: 0.2287 - val_accuracy: 0.9053
# Epoch 79/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2338 - accuracy: 0.9026 - val_loss: 0.2826 - val_accuracy: 0.8854
# Epoch 80/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.2361 - accuracy: 0.9019 - val_loss: 0.2455 - val_accuracy: 0.8969
# Epoch 81/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2201 - accuracy: 0.9085 - val_loss: 0.2215 - val_accuracy: 0.9120
# Epoch 82/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.2342 - accuracy: 0.9048 - val_loss: 0.2419 - val_accuracy: 0.9023
# Epoch 83/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.2249 - accuracy: 0.9077 - val_loss: 0.2319 - val_accuracy: 0.9043
# Epoch 84/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2249 - accuracy: 0.9065 - val_loss: 0.2617 - val_accuracy: 0.8821
# Epoch 85/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.2413 - accuracy: 0.8986 - val_loss: 0.2378 - val_accuracy: 0.8998
# Epoch 86/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.2449 - accuracy: 0.8965 - val_loss: 0.2521 - val_accuracy: 0.8911
# Epoch 87/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2621 - accuracy: 0.8894 - val_loss: 0.2799 - val_accuracy: 0.8849
# Epoch 88/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2591 - accuracy: 0.8927 - val_loss: 0.2462 - val_accuracy: 0.8982
# Epoch 89/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2390 - accuracy: 0.9021 - val_loss: 0.2424 - val_accuracy: 0.8981
# Epoch 90/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2268 - accuracy: 0.9061 - val_loss: 0.2390 - val_accuracy: 0.9017
# Epoch 91/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2336 - accuracy: 0.9041 - val_loss: 0.2555 - val_accuracy: 0.8947
# Epoch 92/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.2535 - accuracy: 0.8970 - val_loss: 0.2618 - val_accuracy: 0.8881
# Epoch 93/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.2376 - accuracy: 0.9029 - val_loss: 0.2455 - val_accuracy: 0.8985
# Epoch 94/100
# 1034/1034 [==============================] - 21s 21ms/step - loss: 0.2394 - accuracy: 0.8994 - val_loss: 0.2405 - val_accuracy: 0.9006
# Epoch 95/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2417 - accuracy: 0.8992 - val_loss: 0.2753 - val_accuracy: 0.8823
# Epoch 96/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2857 - accuracy: 0.8797 - val_loss: 0.2992 - val_accuracy: 0.8742
# Epoch 97/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2780 - accuracy: 0.8848 - val_loss: 0.2722 - val_accuracy: 0.8868
# Epoch 98/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2787 - accuracy: 0.8823 - val_loss: 0.2997 - val_accuracy: 0.8710
# Epoch 99/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2849 - accuracy: 0.8794 - val_loss: 0.2915 - val_accuracy: 0.8744
# Epoch 100/100
# 1034/1034 [==============================] - 22s 21ms/step - loss: 0.2787 - accuracy: 0.8805 - val_loss: 0.2758 - val_accuracy: 0.8784

# %%
# 100
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()

# %%
# 3000
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(X_valid, y_valid)
# Out:
# 259/259 [==============================] - 2s 8ms/step - loss: 0.1810 - accuracy: 0.9302
# [0.18104860186576843, 0.9302465915679932]

# %%
# !ls
# Out:
# healthy  model.h5  parkinson  sample_data

# %%
from google.colab import files
files.download('model.h5')
