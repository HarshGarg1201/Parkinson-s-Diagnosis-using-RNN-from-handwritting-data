# %%
import pandas as pd
import warnings
import re
import requests, zipfile, io, os
import numpy as np
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
warnings.filterwarnings('ignore')

# %%
# download file from url, extract it and store it in the dest_folder
def download_and_extract(url, dest_folder):
  r = requests.get(url)
  z = zipfile.ZipFile(io.BytesIO(r.content))
  z.extractall(dest_folder)

# %%
# define folders and urls
healthy_path = './healthy'
healthy_url = 'http://wwwp.fc.unesp.br/~papa/pub/datasets/Handpd/NewHealthy/Signal.zip'
parkinson_path = './parkinson'
parkinson_url = 'http://wwwp.fc.unesp.br/~papa/pub/datasets/Handpd/NewPatients/Signal.zip'

# %%
download_and_extract(healthy_url, healthy_path)

# %%
download_and_extract(parkinson_url, parkinson_path)

# %%
# actual downloaded signals
healthy_signals = f'{healthy_path}/Signal/'
parkinson_signals = f'{parkinson_path}/Signal/'

# %%
# define Input and labels (0 = healthy, parkinson = 1)
X = []
y = []
seq = 100

# %%
# create dataset with sequence length

# healthy signals
for filename in os.listdir(healthy_signals):
  if re.search('sigSp', filename) is not None:
    df = pd.read_csv(healthy_signals + filename, sep='\s+', header=None, comment='#')
    count = len(df.index) // seq
    for i in range(count):
      X.append((df.iloc[i * seq : (i + 1) * seq]).to_numpy())
      y.append(0)

# parkinson signals
for filename in os.listdir(parkinson_signals):
  if re.search('sigSp', filename) is not None:
    df = pd.read_csv(parkinson_signals + filename, sep='\s+', header=None, comment='#')
    count = len(df.index) // seq
    for i in range(count):
      X.append((df.iloc[i * seq : (i + 1) * seq]).to_numpy())
      y.append(1)

# %%
len(X)
# Out:
# 46901

# %%
# convert lists to np arrays
X = np.array(X)
y = np.array(y)

# %%
X.shape
# Out:
# (46901, 100, 6)

# %%
y.shape
# Out:
# (46901,)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_valid = scaler.transform(X_valid.reshape(-1, X_valid.shape[-1])).reshape(X_valid.shape)

# %%
model = keras.models.Sequential([
keras.layers.GRU(128, return_sequences=True, input_shape=(X_train.shape[1], 6)),
keras.layers.GRU(128),
keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
checkpoint_filepath = "model.h5"
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
history = model.fit(X_train, y_train, epochs = 50, batch_size = 32, validation_data=(X_valid, y_valid), callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/50
# 1173/1173 [==============================] - 14s 12ms/step - loss: 0.4642 - accuracy: 0.7868 - val_loss: 0.3816 - val_accuracy: 0.8352
# Epoch 2/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.3584 - accuracy: 0.8409 - val_loss: 0.3056 - val_accuracy: 0.8657
# Epoch 3/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.2998 - accuracy: 0.8690 - val_loss: 0.2822 - val_accuracy: 0.8733
# Epoch 4/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.2536 - accuracy: 0.8937 - val_loss: 0.2511 - val_accuracy: 0.8973
# Epoch 5/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.2132 - accuracy: 0.9124 - val_loss: 0.2158 - val_accuracy: 0.9158
# Epoch 6/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.1782 - accuracy: 0.9271 - val_loss: 0.1907 - val_accuracy: 0.9258
# Epoch 7/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.1563 - accuracy: 0.9361 - val_loss: 0.1879 - val_accuracy: 0.9262
# Epoch 8/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.1360 - accuracy: 0.9467 - val_loss: 0.1745 - val_accuracy: 0.9340
# Epoch 9/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.1192 - accuracy: 0.9532 - val_loss: 0.1763 - val_accuracy: 0.9389
# Epoch 10/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.1103 - accuracy: 0.9561 - val_loss: 0.1577 - val_accuracy: 0.9415
# Epoch 11/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0977 - accuracy: 0.9623 - val_loss: 0.1650 - val_accuracy: 0.9383
# Epoch 12/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0882 - accuracy: 0.9664 - val_loss: 0.1539 - val_accuracy: 0.9434
# Epoch 13/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0793 - accuracy: 0.9700 - val_loss: 0.1635 - val_accuracy: 0.9420
# Epoch 14/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0761 - accuracy: 0.9713 - val_loss: 0.1587 - val_accuracy: 0.9463
# Epoch 15/50
# 1173/1173 [==============================] - 13s 12ms/step - loss: 0.0683 - accuracy: 0.9748 - val_loss: 0.1526 - val_accuracy: 0.9471
# Epoch 16/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0615 - accuracy: 0.9771 - val_loss: 0.1700 - val_accuracy: 0.9433
# Epoch 17/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0591 - accuracy: 0.9787 - val_loss: 0.1552 - val_accuracy: 0.9492
# Epoch 18/50
# 1173/1173 [==============================] - 14s 12ms/step - loss: 0.0473 - accuracy: 0.9826 - val_loss: 0.1650 - val_accuracy: 0.9486
# Epoch 19/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0536 - accuracy: 0.9795 - val_loss: 0.1613 - val_accuracy: 0.9467
# Epoch 20/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0458 - accuracy: 0.9829 - val_loss: 0.2031 - val_accuracy: 0.9387
# Epoch 21/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0437 - accuracy: 0.9838 - val_loss: 0.1646 - val_accuracy: 0.9483
# Epoch 22/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0441 - accuracy: 0.9842 - val_loss: 0.1715 - val_accuracy: 0.9480
# Epoch 23/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0381 - accuracy: 0.9863 - val_loss: 0.1699 - val_accuracy: 0.9506
# Epoch 24/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0368 - accuracy: 0.9865 - val_loss: 0.1616 - val_accuracy: 0.9499
# Epoch 25/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0339 - accuracy: 0.9878 - val_loss: 0.1646 - val_accuracy: 0.9524
# Epoch 26/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0384 - accuracy: 0.9866 - val_loss: 0.1821 - val_accuracy: 0.9497
# Epoch 27/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0303 - accuracy: 0.9885 - val_loss: 0.1926 - val_accuracy: 0.9449
# Epoch 28/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0290 - accuracy: 0.9899 - val_loss: 0.1766 - val_accuracy: 0.9539
# Epoch 29/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0345 - accuracy: 0.9883 - val_loss: 0.1766 - val_accuracy: 0.9532
# Epoch 30/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0291 - accuracy: 0.9893 - val_loss: 0.1748 - val_accuracy: 0.9517
# Epoch 31/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0264 - accuracy: 0.9909 - val_loss: 0.1877 - val_accuracy: 0.9517
# Epoch 32/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0267 - accuracy: 0.9914 - val_loss: 0.2031 - val_accuracy: 0.9436
# Epoch 33/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0238 - accuracy: 0.9918 - val_loss: 0.1975 - val_accuracy: 0.9485
# Epoch 34/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0327 - accuracy: 0.9881 - val_loss: 0.1864 - val_accuracy: 0.9546
# Epoch 35/50
# 1173/1173 [==============================] - 14s 12ms/step - loss: 0.0254 - accuracy: 0.9910 - val_loss: 0.1825 - val_accuracy: 0.9522
# Epoch 36/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0256 - accuracy: 0.9909 - val_loss: 0.1937 - val_accuracy: 0.9529
# Epoch 37/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0192 - accuracy: 0.9938 - val_loss: 0.2070 - val_accuracy: 0.9530
# Epoch 38/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0316 - accuracy: 0.9891 - val_loss: 0.1922 - val_accuracy: 0.9504
# Epoch 39/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0185 - accuracy: 0.9939 - val_loss: 0.1907 - val_accuracy: 0.9532
# Epoch 40/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0264 - accuracy: 0.9908 - val_loss: 0.2007 - val_accuracy: 0.9498
# Epoch 41/50
# 1173/1173 [==============================] - 14s 12ms/step - loss: 0.0203 - accuracy: 0.9930 - val_loss: 0.2062 - val_accuracy: 0.9484
# Epoch 42/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0211 - accuracy: 0.9924 - val_loss: 0.1976 - val_accuracy: 0.9524
# Epoch 43/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0242 - accuracy: 0.9918 - val_loss: 0.1930 - val_accuracy: 0.9555
# Epoch 44/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0274 - accuracy: 0.9902 - val_loss: 0.2088 - val_accuracy: 0.9482
# Epoch 45/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0204 - accuracy: 0.9926 - val_loss: 0.2063 - val_accuracy: 0.9500
# Epoch 46/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0246 - accuracy: 0.9915 - val_loss: 0.1940 - val_accuracy: 0.9508
# Epoch 47/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0179 - accuracy: 0.9941 - val_loss: 0.2176 - val_accuracy: 0.9489
# Epoch 48/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0234 - accuracy: 0.9922 - val_loss: 0.2328 - val_accuracy: 0.9464
# Epoch 49/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0203 - accuracy: 0.9933 - val_loss: 0.2047 - val_accuracy: 0.9518
# Epoch 50/50
# 1173/1173 [==============================] - 13s 11ms/step - loss: 0.0221 - accuracy: 0.9925 - val_loss: 0.1980 - val_accuracy: 0.9517

# %%
# 100
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()

# %%
# 3000
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(X_valid, y_valid)
# Out:
# 294/294 [==============================] - 1s 5ms/step - loss: 0.1930 - accuracy: 0.9555
# [0.1930488497018814, 0.9555484652519226]

# %%
# !ls
# Out:
# healthy  model.h5  parkinson  sample_data

# %%
from google.colab import files
files.download('model.h5')
