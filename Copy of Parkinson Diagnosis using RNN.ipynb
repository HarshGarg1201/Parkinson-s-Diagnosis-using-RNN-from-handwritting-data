# %%
import pandas as pd
import warnings
import re
import requests, zipfile, io, os
import numpy as np
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
warnings.filterwarnings('ignore')

# %%
# download file from url, extract it and store it in the dest_folder
def download_and_extract(url, dest_folder):
  r = requests.get(url)
  z = zipfile.ZipFile(io.BytesIO(r.content))
  z.extractall(dest_folder)

# %%
# define folders and urls
healthy_path = './healthy'
healthy_url = 'http://wwwp.fc.unesp.br/~papa/pub/datasets/Handpd/NewHealthy/Signal.zip'
parkinson_path = './parkinson'
parkinson_url = 'http://wwwp.fc.unesp.br/~papa/pub/datasets/Handpd/NewPatients/Signal.zip'

# %%
download_and_extract(healthy_url, healthy_path)

# %%
download_and_extract(parkinson_url, parkinson_path)

# %%
# actual downloaded signals
healthy_signals = f'{healthy_path}/Signal/'
parkinson_signals = f'{parkinson_path}/Signal/'

# %%
# define Input and labels (0 = healthy, parkinson = 1)
X = []
y = []
seq = 3000

# %%
# create dataset with sequence length

# healthy signals
for filename in os.listdir(healthy_signals):
  if re.search('sigSp', filename) is not None:
    df = pd.read_csv(healthy_signals + filename, sep='\s+', header=None, comment='#')
    count = len(df.index) // seq
    for i in range(count):
      X.append((df.iloc[i * seq : (i + 1) * seq]).to_numpy())
      y.append(0)

# parkinson signals
for filename in os.listdir(parkinson_signals):
  if re.search('sigSp', filename) is not None:
    df = pd.read_csv(parkinson_signals + filename, sep='\s+', header=None, comment='#')
    count = len(df.index) // seq
    for i in range(count):
      X.append((df.iloc[i * seq : (i + 1) * seq]).to_numpy())
      y.append(1)

# %%
len(X)
# Out:
# 1424

# %%
# convert lists to np arrays
X = np.array(X)
y = np.array(y)

# %%
X.shape
# Out:
# (1424, 3000, 6)

# %%
y.shape
# Out:
# (1424,)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_valid = scaler.transform(X_valid.reshape(-1, X_valid.shape[-1])).reshape(X_valid.shape)

# %%
model = keras.models.Sequential([
keras.layers.GRU(128, return_sequences=True, input_shape=(X_train.shape[1], 6)),
keras.layers.GRU(128),
keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
checkpoint_filepath = "model.h5"
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
history = model.fit(X_train, y_train, epochs = 50, batch_size = 64, validation_data=(X_valid, y_valid), callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/50
# 18/18 [==============================] - 7s 391ms/step - loss: 0.6048 - accuracy: 0.6734 - val_loss: 0.6145 - val_accuracy: 0.7368
# Epoch 2/50
# 18/18 [==============================] - 6s 353ms/step - loss: 0.5687 - accuracy: 0.7507 - val_loss: 0.5900 - val_accuracy: 0.7368
# Epoch 3/50
# 18/18 [==============================] - 6s 353ms/step - loss: 0.5481 - accuracy: 0.7498 - val_loss: 0.5902 - val_accuracy: 0.7368
# Epoch 4/50
# 18/18 [==============================] - 6s 353ms/step - loss: 0.5260 - accuracy: 0.7524 - val_loss: 0.5753 - val_accuracy: 0.7439
# Epoch 5/50
# 18/18 [==============================] - 6s 353ms/step - loss: 0.5124 - accuracy: 0.7638 - val_loss: 0.5460 - val_accuracy: 0.7404
# Epoch 6/50
# 18/18 [==============================] - 6s 353ms/step - loss: 0.4978 - accuracy: 0.7665 - val_loss: 0.5250 - val_accuracy: 0.7614
# Epoch 7/50
# 18/18 [==============================] - 6s 352ms/step - loss: 0.4789 - accuracy: 0.7735 - val_loss: 0.5318 - val_accuracy: 0.7298
# Epoch 8/50
# 18/18 [==============================] - 6s 353ms/step - loss: 0.4824 - accuracy: 0.7884 - val_loss: 0.5174 - val_accuracy: 0.7333
# Epoch 9/50
# 18/18 [==============================] - 6s 351ms/step - loss: 0.4492 - accuracy: 0.7972 - val_loss: 0.5324 - val_accuracy: 0.7544
# Epoch 10/50
# 18/18 [==============================] - 6s 352ms/step - loss: 0.4407 - accuracy: 0.8095 - val_loss: 0.5082 - val_accuracy: 0.7614
# Epoch 11/50
# 18/18 [==============================] - 6s 353ms/step - loss: 0.4230 - accuracy: 0.8218 - val_loss: 0.5129 - val_accuracy: 0.7404
# Epoch 12/50
# 18/18 [==============================] - 6s 354ms/step - loss: 0.4091 - accuracy: 0.8235 - val_loss: 0.5032 - val_accuracy: 0.7579
# Epoch 13/50
# 18/18 [==============================] - 6s 353ms/step - loss: 0.4009 - accuracy: 0.8288 - val_loss: 0.4514 - val_accuracy: 0.7614
# Epoch 14/50
# 18/18 [==============================] - 6s 353ms/step - loss: 0.3863 - accuracy: 0.8402 - val_loss: 0.4463 - val_accuracy: 0.7895
# Epoch 15/50
# 18/18 [==============================] - 6s 353ms/step - loss: 0.3629 - accuracy: 0.8385 - val_loss: 0.4429 - val_accuracy: 0.7895
# Epoch 16/50
# 18/18 [==============================] - 6s 353ms/step - loss: 0.3505 - accuracy: 0.8393 - val_loss: 0.4697 - val_accuracy: 0.7614
# Epoch 17/50
# 18/18 [==============================] - 6s 355ms/step - loss: 0.3595 - accuracy: 0.8411 - val_loss: 0.4315 - val_accuracy: 0.7684
# Epoch 18/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.3506 - accuracy: 0.8490 - val_loss: 0.4242 - val_accuracy: 0.8070
# Epoch 19/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.3271 - accuracy: 0.8622 - val_loss: 0.4271 - val_accuracy: 0.7825
# Epoch 20/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.3100 - accuracy: 0.8639 - val_loss: 0.4800 - val_accuracy: 0.7719
# Epoch 21/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.3561 - accuracy: 0.8367 - val_loss: 0.5143 - val_accuracy: 0.7439
# Epoch 22/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.3313 - accuracy: 0.8534 - val_loss: 0.4540 - val_accuracy: 0.7965
# Epoch 23/50
# 18/18 [==============================] - 6s 355ms/step - loss: 0.3076 - accuracy: 0.8683 - val_loss: 0.4259 - val_accuracy: 0.7649
# Epoch 24/50
# 18/18 [==============================] - 6s 355ms/step - loss: 0.2946 - accuracy: 0.8797 - val_loss: 0.4090 - val_accuracy: 0.7895
# Epoch 25/50
# 18/18 [==============================] - 6s 354ms/step - loss: 0.2753 - accuracy: 0.8780 - val_loss: 0.4456 - val_accuracy: 0.8035
# Epoch 26/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.2729 - accuracy: 0.8973 - val_loss: 0.4378 - val_accuracy: 0.8070
# Epoch 27/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.2805 - accuracy: 0.8797 - val_loss: 0.4481 - val_accuracy: 0.7754
# Epoch 28/50
# 18/18 [==============================] - 6s 355ms/step - loss: 0.2568 - accuracy: 0.8973 - val_loss: 0.3850 - val_accuracy: 0.8105
# Epoch 29/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.2451 - accuracy: 0.9078 - val_loss: 0.4335 - val_accuracy: 0.8140
# Epoch 30/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.2432 - accuracy: 0.9025 - val_loss: 0.4497 - val_accuracy: 0.8140
# Epoch 31/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.2481 - accuracy: 0.8955 - val_loss: 0.3782 - val_accuracy: 0.8246
# Epoch 32/50
# 18/18 [==============================] - 6s 355ms/step - loss: 0.2254 - accuracy: 0.9104 - val_loss: 0.4134 - val_accuracy: 0.7965
# Epoch 33/50
# 18/18 [==============================] - 6s 355ms/step - loss: 0.2072 - accuracy: 0.9131 - val_loss: 0.3810 - val_accuracy: 0.8386
# Epoch 34/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.2017 - accuracy: 0.9210 - val_loss: 0.4912 - val_accuracy: 0.8140
# Epoch 35/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.2097 - accuracy: 0.9175 - val_loss: 0.4368 - val_accuracy: 0.8035
# Epoch 36/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.2380 - accuracy: 0.9008 - val_loss: 0.4552 - val_accuracy: 0.8140
# Epoch 37/50
# 18/18 [==============================] - 6s 355ms/step - loss: 0.2402 - accuracy: 0.9008 - val_loss: 0.4012 - val_accuracy: 0.8211
# Epoch 38/50
# 18/18 [==============================] - 6s 355ms/step - loss: 0.1932 - accuracy: 0.9245 - val_loss: 0.4040 - val_accuracy: 0.8211
# Epoch 39/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.1740 - accuracy: 0.9333 - val_loss: 0.4701 - val_accuracy: 0.8351
# Epoch 40/50
# 18/18 [==============================] - 6s 355ms/step - loss: 0.1673 - accuracy: 0.9280 - val_loss: 0.5053 - val_accuracy: 0.7965
# Epoch 41/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.1626 - accuracy: 0.9403 - val_loss: 0.4612 - val_accuracy: 0.8175
# Epoch 42/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.1419 - accuracy: 0.9500 - val_loss: 0.5109 - val_accuracy: 0.7965
# Epoch 43/50
# 18/18 [==============================] - 6s 355ms/step - loss: 0.1478 - accuracy: 0.9464 - val_loss: 0.4672 - val_accuracy: 0.8281
# Epoch 44/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.2258 - accuracy: 0.9122 - val_loss: 0.4411 - val_accuracy: 0.8105
# Epoch 45/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.1980 - accuracy: 0.9219 - val_loss: 0.4691 - val_accuracy: 0.8000
# Epoch 46/50
# 18/18 [==============================] - 6s 355ms/step - loss: 0.1507 - accuracy: 0.9473 - val_loss: 0.4810 - val_accuracy: 0.8140
# Epoch 47/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.1146 - accuracy: 0.9649 - val_loss: 0.4853 - val_accuracy: 0.7965
# Epoch 48/50
# 18/18 [==============================] - 6s 357ms/step - loss: 0.1029 - accuracy: 0.9631 - val_loss: 0.5642 - val_accuracy: 0.8070
# Epoch 49/50
# 18/18 [==============================] - 6s 355ms/step - loss: 0.0916 - accuracy: 0.9693 - val_loss: 0.5405 - val_accuracy: 0.8035
# Epoch 50/50
# 18/18 [==============================] - 6s 356ms/step - loss: 0.0864 - accuracy: 0.9675 - val_loss: 0.5682 - val_accuracy: 0.8351

# %%
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(X_valid, y_valid)
# Out:
# 9/9 [==============================] - 1s 92ms/step - loss: 0.3810 - accuracy: 0.8386
# [0.38095471262931824, 0.8385964632034302]

# %%
# !ls
# Out:
# healthy  model.h5  parkinson  sample_data

# %%
from google.colab import files
files.download('model.h5')
